# %%
# %load_ext sql
from sqlalchemy import create_engine
# %sql postgresql://gnsiobsurufrtp:0d57af453839e69ec694c32f5af9f06d938697b08d2c4e279403aa9eeed31661@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://postgres:@localhost:5432/postgres

# %% [markdown]
# VIEWING THE FIRST 10 ROWS OF THE AIRBNB_LISBON TABLE

# %%
# %sql SELECT * FROM airbnb_lisbon LIMIT 10
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 10 rows affected.
# [(14708916, 91501272, 'Shared room', 'Santo António', 19, 4.5, 4, 1.0, None, 30.0, 'LOW COST HOSTEL MARQUES GARDENS 4 BED DORM', datetime.datetime(2017, 7, 28, 1, 19, 53, 215272), 38.723987, -9.146613, '0101000020E61000003F56F0DB104B22C055DD239BAB5C4340'),
#  (7465447, 704061, 'Shared room', 'Avenidas Novas', 4, 3.5, 6, 1.0, None, 39.0, 'Room in Lisbon center', datetime.datetime(2017, 7, 28, 1, 19, 53, 206052), 38.735061, -9.15451, '0101000020E610000057CF49EF1B4F22C054C8957A165E4340'),
#  (11058290, 1379661, 'Shared room', 'Santa Maria Maior', 38, 4.5, 8, 1.0, None, 39.0, 'Bed in a 8-bed dorm @ This Is Lisbon Hostel', datetime.datetime(2017, 7, 28, 1, 19, 52, 34547), 38.715726, -9.132671, '0101000020E610000057410C74ED4322C0CD72D9E89C5B4340'),
#  (9019111, 46762399, 'Shared room', 'Avenidas Novas', 9, 4.0, 6, 1.0, None, 37.0, 'Shared mixed bunkbed room 1', datetime.datetime(2017, 7, 28, 1, 19, 52, 20396), 38.729017, -9.149932, '0101000020E61000006C3F19E3C34C22C0309DD66D505D4340'),
#  (3123304, 8488955, 'Shared room', 'Arroios', 0, 0.0, 2, 1.0, None, 480.0, 'quarto no centro de lisboa', datetime.datetime(2017, 7, 28, 1, 19, 50, 401364), 38.721617, -9.136208, '0101000020E61000003AE8120EBD4522C06B9E23F25D5C4340'),
#  (3110303, 15806678, 'Shared room', 'Arroios', 0, 0.0, 2, 1.0, None, 480.0, 'UEFA LISBOA', datetime.datetime(2017, 7, 28, 1, 19, 50, 398554), 38.732262, -9.134285, '0101000020E6100000CDAFE600C14422C0410DDFC2BA5D4340'),
#  (13514728, 77597089, 'Shared room', 'Lumiar', 0, 0.0, 2, 1.0, None, 180.0, 'Autocaravana com condutor', datetime.datetime(2017, 7, 28, 1, 19, 48, 104348), 38.761582, -9.170725, '0101000020E61000001D386744695722C0739CDB847B614340'),
#  (3049237, 15020890, 'Shared room', 'Areeiro', 0, 0.0, 1, 1.0, None, 174.0, None, datetime.datetime(2017, 7, 28, 1, 19, 48, 101673), 38.738405, -9.134452, '0101000020E61000007AC37DE4D64422C0F819170E845E4340'),
#  (19037719, 8477034, 'Shared room', 'São Vicente', 0, 0.0, 4, 1.0, None, 144.0, 'Orange placito', datetime.datetime(2017, 7, 28, 1, 19, 48, 98744), 38.718112, -9.128895, '0101000020E6100000603C8386FE4122C0BD6E1118EB5B4340'),
#  (17286309, 95779617, 'Shared room', 'Arroios', 0, 0.0, 1, 1.0, None, 144.0, 'Apartamento, quarto sala', datetime.datetime(2017, 7, 28, 1, 19, 47, 156007), 38.732699, -9.135252, '0101000020E6100000EB6F09C03F4522C0EC67B114C95D4340')]

# %% [markdown]
# REMOVING UNWANTED COLUMNS FROM THE TABLE

# %%
# %%sql
# ALTER TABLE airbnb_lisbon
# DROP COLUMN survey_id,
# DROP COLUMN country,
# DROP COLUMN city,
# DROP COLUMN borough,
# DROP COLUMN minstay,
# DROP COLUMN bathrooms;
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# []

# %% [markdown]
# VIEWING THE FIRST 5 ROWS OF THE AIRBNB_LISBON TABLE TO CHECK IF THE COLUMNS WERE DELETED

# %%
# %sql SELECT * FROM airbnb_lisbon LIMIT 5
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 5 rows affected.
# [(14708916, 91501272, 'Shared room', 'Santo António', 19, 4.5, 4, 1.0, 30.0, 'LOW COST HOSTEL MARQUES GARDENS 4 BED DORM', datetime.datetime(2017, 7, 28, 1, 19, 53, 215272), 38.723987, -9.146613, '0101000020E61000003F56F0DB104B22C055DD239BAB5C4340'),
#  (7465447, 704061, 'Shared room', 'Avenidas Novas', 4, 3.5, 6, 1.0, 39.0, 'Room in Lisbon center', datetime.datetime(2017, 7, 28, 1, 19, 53, 206052), 38.735061, -9.15451, '0101000020E610000057CF49EF1B4F22C054C8957A165E4340'),
#  (11058290, 1379661, 'Shared room', 'Santa Maria Maior', 38, 4.5, 8, 1.0, 39.0, 'Bed in a 8-bed dorm @ This Is Lisbon Hostel', datetime.datetime(2017, 7, 28, 1, 19, 52, 34547), 38.715726, -9.132671, '0101000020E610000057410C74ED4322C0CD72D9E89C5B4340'),
#  (9019111, 46762399, 'Shared room', 'Avenidas Novas', 9, 4.0, 6, 1.0, 37.0, 'Shared mixed bunkbed room 1', datetime.datetime(2017, 7, 28, 1, 19, 52, 20396), 38.729017, -9.149932, '0101000020E61000006C3F19E3C34C22C0309DD66D505D4340'),
#  (3123304, 8488955, 'Shared room', 'Arroios', 0, 0.0, 2, 1.0, 480.0, 'quarto no centro de lisboa', datetime.datetime(2017, 7, 28, 1, 19, 50, 401364), 38.721617, -9.136208, '0101000020E61000003AE8120EBD4522C06B9E23F25D5C4340')]

# %% [markdown]
# CHECKING NULL VALUES

# %%
# %sql SELECT * FROM airbnb_lisbon WHERE name IS NULL
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 28 rows affected.
# [(3049237, 15020890, 'Shared room', 'Areeiro', 0, 0.0, 1, 1.0, 174.0, None, datetime.datetime(2017, 7, 28, 1, 19, 48, 101673), 38.738405, -9.134452, '0101000020E61000007AC37DE4D64422C0F819170E845E4340'),
#  (16269727, 50575236, 'Entire home/apt', 'Santo António', 0, 0.0, 2, 1.0, 347.0, None, datetime.datetime(2017, 7, 28, 0, 30, 26, 83432), 38.718818, -9.150706, '0101000020E6100000389F3A56294D22C058E36C3A025C4340'),
#  (11961196, 43258704, 'Entire home/apt', 'Santa Clara', 0, 0.0, 3, 1.0, 113.0, None, datetime.datetime(2017, 7, 28, 0, 6, 6, 889347), 38.782385, -9.158523, '0101000020E6100000DF5339ED295122C0C3F0113125644340'),
#  (3129185, 15891628, 'Entire home/apt', 'Penha de França', 0, 0.0, 6, 2.0, 1201.0, None, datetime.datetime(2017, 7, 27, 23, 12, 13, 730932), 38.734562, -9.130074, '0101000020E6100000AC1E300F994222C03271AB20065E4340'),
#  (3129127, 15891325, 'Entire home/apt', 'Benfica', 0, 0.0, 4, 1.0, 1201.0, None, datetime.datetime(2017, 7, 27, 23, 12, 13, 705307), 38.755116, -9.197867, '0101000020E61000004FEACBD24E6522C0DA571EA4A7604340'),
#  (3104053, 4967811, 'Entire home/apt', 'Campo de Ourique', 0, 0.0, 5, 3.0, 840.0, None, datetime.datetime(2017, 7, 27, 23, 12, 12, 338974), 38.719404, -9.169104, '0101000020E6100000DE3EABCC945622C0484E266E155C4340'),
#  (3079140, 15011587, 'Entire home/apt', 'São Domingos de Benfica', 0, 0.0, 2, 1.0, 781.0, None, datetime.datetime(2017, 7, 27, 23, 12, 12, 326194), 38.744064, -9.174446, '0101000020E610000006D671FC505922C0C310397D3D5F4340'),
#  (3118028, 15843103, 'Entire home/apt', 'Benfica', 0, 0.0, 2, 1.0, 840.0, None, datetime.datetime(2017, 7, 27, 23, 12, 12, 321135), 38.7528, -9.195614, '0101000020E61000008D47A984276422C0E3361AC05B604340'),
#  (3118839, 15846016, 'Entire home/apt', 'Lumiar', 0, 0.0, 6, 3.0, 600.0, None, datetime.datetime(2017, 7, 27, 23, 12, 11, 247552), 38.767741, -9.155973, '0101000020E6100000361E6CB1DB4F22C030664B5645624340'),
#  (2988197, 15237172, 'Entire home/apt', 'Avenidas Novas', 0, 0.0, 2, 2.0, 240.0, None, datetime.datetime(2017, 7, 27, 23, 11, 50, 249008), 38.729434, -9.157139, '0101000020E610000030DAE385745022C0944BE3175E5D4340'),
#  (13722176, 26166365, 'Entire home/apt', 'São Vicente', 2, 0.0, 5, 3.0, 180.0, None, datetime.datetime(2017, 7, 27, 23, 0, 46, 980570), 38.716687, -9.131072, '0101000020E6100000B6D782DE1B4322C0F33B4D66BC5B4340'),
#  (8646030, 20643180, 'Entire home/apt', 'Areeiro', 0, 0.0, 5, 3.0, 144.0, None, datetime.datetime(2017, 7, 27, 22, 53, 40, 764849), 38.744359, -9.141114, '0101000020E6100000F7031E18404822C0DCBDDC27475F4340'),
#  (11603154, 2573566, 'Entire home/apt', 'Arroios', 0, 0.0, 4, 1.0, 118.0, None, datetime.datetime(2017, 7, 27, 22, 27, 55, 745278), 38.7345, -9.143763, '0101000020E6100000ECBFCE4D9B4922C0BC749318045E4340'),
#  (3763696, 19278006, 'Entire home/apt', 'Santo António', 0, 0.0, 1, 2.0, 90.0, None, datetime.datetime(2017, 7, 27, 21, 26, 27, 801915), 38.717163, -9.154922, '0101000020E6100000A0DCB6EF514F22C05C7347FFCB5B4340'),
#  (8546448, 44988589, 'Entire home/apt', 'São Vicente', 1, 0.0, 6, 2.0, 92.0, None, datetime.datetime(2017, 7, 27, 21, 13, 34, 400208), 38.714844, -9.127432, '0101000020E610000081ED60C43E4122C0F4DE1802805B4340'),
#  (5090022, 24493655, 'Entire home/apt', 'Estrela', 0, 0.0, 4, 1.0, 72.0, None, datetime.datetime(2017, 7, 27, 19, 56, 37, 736429), 38.713792, -9.157036, '0101000020E6100000DD96C805675022C0BE1248895D5B4340'),
#  (5883731, 727771, 'Entire home/apt', 'São Vicente', 31, 5.0, 6, 2.0, 72.0, None, datetime.datetime(2017, 7, 27, 19, 48, 32, 79371), 38.716125, -9.123046, '0101000020E6100000A7CEA3E2FF3E22C08B6CE7FBA95B4340'),
#  (4984241, 25693256, 'Entire home/apt', 'Estrela', 97, 4.5, 2, 0.0, 42.0, None, datetime.datetime(2017, 7, 27, 18, 42, 3, 144541), 38.710058, -9.158546, '0101000020E6100000BFD2F9F02C5122C0AF21382EE35A4340'),
#  (12558671, 68074381, 'Entire home/apt', 'Estrela', 0, 0.0, 4, 2.0, 60.0, None, datetime.datetime(2017, 7, 27, 18, 47, 49, 146491), 38.711725, -9.170751, '0101000020E6100000C284D1AC6C5722C0705F07CE195B4340'),
#  (3049375, 15020890, 'Private room', 'Areeiro', 0, 0.0, 3, 1.0, 347.0, None, datetime.datetime(2017, 7, 27, 17, 58, 46, 470287), 38.73802, -9.132328, '0101000020E6100000AFB0E07EC04322C09FE57970775E4340'),
#  (2990877, 9866194, 'Private room', 'Benfica', 0, 0.0, 2, 1.0, 336.0, None, datetime.datetime(2017, 7, 27, 17, 58, 46, 451444), 38.748791, -9.200017, '0101000020E6100000BF49D3A0686622C002452C62D85F4340'),
#  (4724680, 1133152, 'Private room', 'Estrela', 0, 0.0, 2, 1.0, 132.0, None, datetime.datetime(2017, 7, 27, 17, 58, 33, 313484), 38.709653, -9.161107, '0101000020E61000003750E09D7C5222C01041D5E8D55A4340'),
#  (5725570, 1794425, 'Private room', 'Misericórdia', 13, 5.0, 2, 1.0, 60.0, None, datetime.datetime(2017, 7, 27, 17, 45, 50, 134567), 38.714272, -9.151167, '0101000020E61000000778D2C2654D22C06939D0436D5B4340'),
#  (12732216, 69233518, 'Private room', 'Santo António', 2, 0.0, 2, 1.0, 42.0, None, datetime.datetime(2017, 7, 27, 17, 44, 58, 974205), 38.717859, -9.142754, '0101000020E610000012BF620D174922C0D311C0CDE25B4340'),
#  (9454593, 11663712, 'Private room', 'Santo António', 0, 0.0, 1, 1.0, 18.0, None, datetime.datetime(2017, 7, 27, 16, 29, 40, 221077), 38.717874, -9.154226, '0101000020E6100000C362D4B5F64E22C00953944BE35B4340'),
#  (15949172, 103527577, 'Private room', 'São Vicente', 29, 5.0, 2, 1.0, 35.0, None, datetime.datetime(2017, 7, 27, 16, 23, 5, 673866), 38.71969, -9.132201, '0101000020E61000003BFF76D9AF4322C00EA14ACD1E5C4340'),
#  (6821663, 3991816, 'Private room', 'Alvalade', 15, 5.0, 1, 1.0, 36.0, None, datetime.datetime(2017, 7, 27, 16, 17, 10, 583496), 38.749925, -9.136046, '0101000020E6100000D48041D2A74522C0F5B9DA8AFD5F4340'),
#  (13063207, 67693269, 'Private room', 'Santa Maria Maior', 52, 5.0, 2, 1.0, 24.0, None, datetime.datetime(2017, 7, 27, 16, 14, 48, 88472), 38.714619, -9.134266, '0101000020E6100000F2ED5D83BE4422C0D40CA9A2785B4340')]

# %% [markdown]
# REMOVING NULL VALUES/ROWS FROM THE COLUMN NAME

# %%
# %sql DELETE FROM airbnb_lisbon WHERE name IS NULL;
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 28 rows affected.
# []

# %% [markdown]
# CHECKING IF THE NULL VALUES FROM COLUMN NAME WERE DELETED

# %%
# %sql SELECT COUNT(name) FROM airbnb_lisbon WHERE name IS NULL
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [(0,)]

# %% [markdown]
# VIEWING THE FIRST 10 ROWS AFTER REMOVING NULL VALUES AND UNWANTED COLUMNS

# %%
# %sql SELECT * FROM airbnb_lisbon LIMIT 10
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 10 rows affected.
# [(14708916, 91501272, 'Shared room', 'Santo António', 19, 4.5, 4, 1.0, 30.0, 'LOW COST HOSTEL MARQUES GARDENS 4 BED DORM', datetime.datetime(2017, 7, 28, 1, 19, 53, 215272), 38.723987, -9.146613, '0101000020E61000003F56F0DB104B22C055DD239BAB5C4340'),
#  (7465447, 704061, 'Shared room', 'Avenidas Novas', 4, 3.5, 6, 1.0, 39.0, 'Room in Lisbon center', datetime.datetime(2017, 7, 28, 1, 19, 53, 206052), 38.735061, -9.15451, '0101000020E610000057CF49EF1B4F22C054C8957A165E4340'),
#  (11058290, 1379661, 'Shared room', 'Santa Maria Maior', 38, 4.5, 8, 1.0, 39.0, 'Bed in a 8-bed dorm @ This Is Lisbon Hostel', datetime.datetime(2017, 7, 28, 1, 19, 52, 34547), 38.715726, -9.132671, '0101000020E610000057410C74ED4322C0CD72D9E89C5B4340'),
#  (9019111, 46762399, 'Shared room', 'Avenidas Novas', 9, 4.0, 6, 1.0, 37.0, 'Shared mixed bunkbed room 1', datetime.datetime(2017, 7, 28, 1, 19, 52, 20396), 38.729017, -9.149932, '0101000020E61000006C3F19E3C34C22C0309DD66D505D4340'),
#  (3123304, 8488955, 'Shared room', 'Arroios', 0, 0.0, 2, 1.0, 480.0, 'quarto no centro de lisboa', datetime.datetime(2017, 7, 28, 1, 19, 50, 401364), 38.721617, -9.136208, '0101000020E61000003AE8120EBD4522C06B9E23F25D5C4340'),
#  (3110303, 15806678, 'Shared room', 'Arroios', 0, 0.0, 2, 1.0, 480.0, 'UEFA LISBOA', datetime.datetime(2017, 7, 28, 1, 19, 50, 398554), 38.732262, -9.134285, '0101000020E6100000CDAFE600C14422C0410DDFC2BA5D4340'),
#  (13514728, 77597089, 'Shared room', 'Lumiar', 0, 0.0, 2, 1.0, 180.0, 'Autocaravana com condutor', datetime.datetime(2017, 7, 28, 1, 19, 48, 104348), 38.761582, -9.170725, '0101000020E61000001D386744695722C0739CDB847B614340'),
#  (19037719, 8477034, 'Shared room', 'São Vicente', 0, 0.0, 4, 1.0, 144.0, 'Orange placito', datetime.datetime(2017, 7, 28, 1, 19, 48, 98744), 38.718112, -9.128895, '0101000020E6100000603C8386FE4122C0BD6E1118EB5B4340'),
#  (17286309, 95779617, 'Shared room', 'Arroios', 0, 0.0, 1, 1.0, 144.0, 'Apartamento, quarto sala', datetime.datetime(2017, 7, 28, 1, 19, 47, 156007), 38.732699, -9.135252, '0101000020E6100000EB6F09C03F4522C0EC67B114C95D4340'),
#  (1006509, 5534910, 'Shared room', 'Santo António', 0, 0.0, 8, 1.0, 121.0, 'Shared Dorms Lisbon', datetime.datetime(2017, 7, 28, 1, 19, 46, 442680), 38.715926, -9.144646, '0101000020E610000093FE5E0A0F4A22C0952D9276A35B4340')]
