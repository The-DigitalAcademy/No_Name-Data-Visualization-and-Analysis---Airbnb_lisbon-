# %%
# %load_ext sql
from sqlalchemy import create_engine
# %sql postgresql://gnsiobsurufrtp:0d57af453839e69ec694c32f5af9f06d938697b08d2c4e279403aa9eeed31661@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r

# %%
# %sql postgresql://postgres:@localhost:5432/postgres

# %%
# %%sql
# ALTER TABLE airbnb_lisbon
# ALTER COLUMN bedrooms TYPE INT;
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# []

# %% [markdown]
# VIEWING THE FIRST 10 ROWS OF THE AIRBNB_LISBON TABLE

# %%
# %sql SELECT * FROM airbnb_lisbon LIMIT 10
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 10 rows affected.
# [(14708916, 91501272, 'Shared room', 'Santo António', 19, 4.5, 4, 1, 30.0, 'LOW COST HOSTEL MARQUES GARDENS 4 BED DORM', datetime.datetime(2017, 7, 28, 1, 19, 53, 215272), 38.723987, -9.146613, '0101000020E61000003F56F0DB104B22C055DD239BAB5C4340'),
#  (7465447, 704061, 'Shared room', 'Avenidas Novas', 4, 3.5, 6, 1, 39.0, 'Room in Lisbon center', datetime.datetime(2017, 7, 28, 1, 19, 53, 206052), 38.735061, -9.15451, '0101000020E610000057CF49EF1B4F22C054C8957A165E4340'),
#  (11058290, 1379661, 'Shared room', 'Santa Maria Maior', 38, 4.5, 8, 1, 39.0, 'Bed in a 8-bed dorm @ This Is Lisbon Hostel', datetime.datetime(2017, 7, 28, 1, 19, 52, 34547), 38.715726, -9.132671, '0101000020E610000057410C74ED4322C0CD72D9E89C5B4340'),
# ...

# %% [markdown]
# REMOVING UNWANTED COLUMNS FROM THE TABLE

# %%
# %%sql
# ALTER TABLE airbnb_lisbon
# DROP COLUMN survey_id,
# DROP COLUMN country,
# DROP COLUMN city,
# DROP COLUMN borough,
# DROP COLUMN minstay,
# DROP COLUMN bathrooms
# ;
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# (psycopg2.errors.UndefinedColumn) column "survey_id" of relation "airbnb_lisbon" does not exist
#
# [SQL: ALTER TABLE airbnb_lisbon
# DROP COLUMN survey_id,
# DROP COLUMN country,
# DROP COLUMN city,
# DROP COLUMN borough,
# DROP COLUMN minstay,
# DROP COLUMN bathrooms
# ;]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# VIEWING THE FIRST 5 ROWS OF THE AIRBNB_LISBON TABLE TO CHECK IF THE COLUMNS WERE DELETED

# %%
# %sql SELECT * FROM airbnb_lisbon LIMIT 5
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 5 rows affected.
# [(14708916, 91501272, 'Shared room', 'Santo António', 19, 4.5, 4, 1, 30.0, 'LOW COST HOSTEL MARQUES GARDENS 4 BED DORM', datetime.datetime(2017, 7, 28, 1, 19, 53, 215272), 38.723987, -9.146613, '0101000020E61000003F56F0DB104B22C055DD239BAB5C4340'),
#  (7465447, 704061, 'Shared room', 'Avenidas Novas', 4, 3.5, 6, 1, 39.0, 'Room in Lisbon center', datetime.datetime(2017, 7, 28, 1, 19, 53, 206052), 38.735061, -9.15451, '0101000020E610000057CF49EF1B4F22C054C8957A165E4340'),
#  (11058290, 1379661, 'Shared room', 'Santa Maria Maior', 38, 4.5, 8, 1, 39.0, 'Bed in a 8-bed dorm @ This Is Lisbon Hostel', datetime.datetime(2017, 7, 28, 1, 19, 52, 34547), 38.715726, -9.132671, '0101000020E610000057410C74ED4322C0CD72D9E89C5B4340'),
# ...

# %% [markdown]
# CHECKING NULL VALUES

# %%
# %sql SELECT * FROM airbnb_lisbon WHERE name IS NULL
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 0 rows affected.
# []

# %% [markdown]
# REMOVING NULL VALUES/ROWS FROM THE COLUMN NAME

# %%
# %sql DELETE FROM airbnb_lisbon WHERE name IS NULL;
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 0 rows affected.
# []

# %% [markdown]
# CHECKING IF THE NULL VALUES FROM COLUMN NAME WERE DELETED

# %%
# %sql SELECT COUNT(name) FROM airbnb_lisbon WHERE name IS NULL
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [(0,)]

# %% [markdown]
# VIEWING THE FIRST 10 ROWS AFTER REMOVING NULL VALUES AND UNWANTED COLUMNS

# %%
# %sql SELECT * FROM airbnb_lisbon LIMIT 10
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 10 rows affected.
# [(14708916, 91501272, 'Shared room', 'Santo António', 19, 4.5, 4, 1, 30.0, 'LOW COST HOSTEL MARQUES GARDENS 4 BED DORM', datetime.datetime(2017, 7, 28, 1, 19, 53, 215272), 38.723987, -9.146613, '0101000020E61000003F56F0DB104B22C055DD239BAB5C4340'),
#  (7465447, 704061, 'Shared room', 'Avenidas Novas', 4, 3.5, 6, 1, 39.0, 'Room in Lisbon center', datetime.datetime(2017, 7, 28, 1, 19, 53, 206052), 38.735061, -9.15451, '0101000020E610000057CF49EF1B4F22C054C8957A165E4340'),
#  (11058290, 1379661, 'Shared room', 'Santa Maria Maior', 38, 4.5, 8, 1, 39.0, 'Bed in a 8-bed dorm @ This Is Lisbon Hostel', datetime.datetime(2017, 7, 28, 1, 19, 52, 34547), 38.715726, -9.132671, '0101000020E610000057410C74ED4322C0CD72D9E89C5B4340'),
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# HOW MANY TYPES OF ROOMS ARE IN LISBON?

# %%
types_vs_number=%sql select count(room_type),room_type from airbnb_lisbon Group by room_type

    
num_of_roomtype = []
room_types = []
 
for i in types_vs_number:
    num_of_roomtype.append(i[0])
    room_types.append(i[1])

plt.figure(figsize=(17,8))
plt.bar(room_types,num_of_roomtype)
plt.ylabel("number of rooms")
plt.xlabel("type of rooms")

plt.title('Types and Number of Rooms')
plt.show()
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 3 rows affected.

# %% [markdown]
# COMPARING REVIEWS AND OVERALL SATISFACTION

# %%
over_rev=%sql select reviews, overall_satisfaction from airbnb_lisbon 

reviews = []
overall_satisfaction = []
 
for i in over_rev:
    reviews.append(i[0])
    overall_satisfaction.append(i[1])

plt.figure(figsize=(17,8))
plt.scatter(overall_satisfaction,reviews,color='green')
plt.ylabel("reviews")
plt.xlabel("overall satisfaction")
plt.xticks(rotation=0)

plt.title('Overall Satisfaction VS Reviews')
plt.show()
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 13550 rows affected.

# %% [markdown]
# WHICH 5 NEIGHBORHOOD HAS HIGHEST NUMBER OF REVIEWS

# %% [markdown]
# WHAT IS THE AVERAGE OVERALL SATISFACTION IN EACH NEIGHBORHOOD?

# %%
average_overrall_satisfaction = %sql select avg(overall_satisfaction), neighborhood from airbnb_lisbon group by neighborhood order by avg(overall_satisfaction) desc limit 20

overall_satisfaction = []
neighborhood = []
width = 0.2
for i in average_overrall_satisfaction:
    overall_satisfaction.append(i[0])
    neighborhood.append(i[1])


plt.figure(figsize=(17,8))
plt.bar( neighborhood,overall_satisfaction, color = 'blue')
plt.ylabel("Average overall satisfaction")
plt.xlabel("neighbourhood")
plt.xticks(rotation=80)
plt.title("Average overall satisfaction")
plt.legend()
plt.ylim(0.0,4.0)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 20 rows affected.

# %% [markdown]
# IN WHICH NEIGHBORHOOD YOU CAN SPEND THE MOST OR LEAST?

# %%
import folium


lati_longi_abv_avg = %sql select neighborhood, latitude, longitude from airbnb_lisbon where price > 50 limit 230
lati_longi_blw_avg = %sql select neighborhood, latitude, longitude from airbnb_lisbon where price < 20 limit 230


m = folium.Map(location = [38.723987,-9.146613])
for c, i in enumerate(lati_longi_abv_avg):
    folium.Marker(location = list(i[1:3]),icon=folium.Icon(color="red")).add_to(m)
    folium.Marker(location = list(lati_longi_blw_avg[c][1:3]),icon=folium.Icon(color="green")).add_to(m)
m
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 230 rows affected.
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 230 rows affected.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...

# %%
room_host=%sql select COUNT(room_type) AS num_rooms, host_id FROM airbnb_lisbon GROUP BY host_id ORDER BY COUNT(room_type) DESC limit 10
room_host
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 10 rows affected.
# [(185, 3953109),
#  (108, 1756107),
#  (103, 106149355),
#  (86, 136003091),
#  (66, 11707167),
#  (65, 140893245),
#  (60, 7564916),
#  (57, 1549585),
#  (50, 2372087),
#  (47, 141121552)]

# %% [markdown]
# HOW MANY ROOMS PER HOST?

# %%
room_host=%sql select COUNT(room_type) AS num_rooms, host_id FROM airbnb_lisbon GROUP BY host_id ORDER BY COUNT(room_type) DESC limit 5
room_host

num_rooms = []
host = []

for i in room_host:
    num_rooms.append(i[0])
    host.append(i[1])

plt.figure(figsize=(17,8))   
plt.axis("equal")
plt.pie(num_rooms, shadow=True, autopct='%1.1f%%',radius=1.0, startangle=90)
plt.title('Number of rooms per host')
plt.legend(labels=host,fontsize=9)
plt.show()
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 5 rows affected.

# %% [markdown]
# WHAT IS THE AVERAGE PRICE FOR EACH ROOM TYPE?

# %%
price_roomtypes=%sql select avg(price) AS PRICES, room_type from  airbnb_lisbon GROUP BY room_type ORDER BY avg(price) desc limit 5
price_roomtypes

price = []
room_type = []

for i in price_roomtypes:
    price.append(i[0])
    room_type.append(i[1])

plt.figure(figsize=(17,8))    
plt.bar(room_type, price, color='green')
plt.ylabel("average prices(Є/Euro)")
plt.xlabel("room types")
plt.xticks(rotation=30)
plt.title('Average Prices vs Room Types')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 3 rows affected.

# %% [markdown]
# HOW MANY ROOM TYPE ARE IN EACH NEIGHBORHOOD?

# %%
import seaborn as sns 
price_roomtypes=%sql select count(room_type) AS count_rooms ,neighborhood ,room_type from  airbnb_lisbon  GROUP BY room_type,neighborhood  ORDER BY count(room_type) desc 


cnt_rooms = []
neibor = []
room_type=[]
 
for i in price_roomtypes:
    cnt_rooms.append(i[0])
    neibor.append(i[1])
    room_type.append(i[2])
plt.figure(figsize=(17,8))
sns.barplot(x=neibor, y= cnt_rooms,  hue=room_type, palette='spring')
plt.xticks(rotation=60)
plt.ylabel("number of rooms ")
plt.xlabel("neighborhood")
plt.xticks(rotation=70)

plt.title('Number of room types per Neighborhood')
plt.show()
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 68 rows affected.

# %% [markdown]
# WHAT IS THE MOST AND LEAST YOU CAN SPEND IN EACH NEIGHBORHOOD?

# %% [markdown]
# HOW MANY HOSTS ARE IN EACH NEIGHBOOD?

# %%
total_number_of_landlords = %sql select count(host_id), neighborhood from airbnb_lisbon group by neighborhood order by count(host_id) desc LIMIT 5

host_id = []
neighborhood = []

for i in total_number_of_landlords:
    host_id.append(i[0])
    neighborhood.append(i[1])

plt.figure(figsize=(17,8))   
plt.axis("equal")
plt.pie(host_id, shadow=True, autopct='%1.1f%%',radius=1.0, labels=neighborhood, startangle=90)
plt.title('Number of host per neighborhood')

plt.show()
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 5 rows affected.

# %% [markdown]
# COMPARING PRICE WITH THE HIGHEST REVIEW

# %%
price_rev=%sql select reviews, price from airbnb_lisbon 

rev = []
prc = []
 
for i in price_rev:
    prc.append(i[0])
    rev.append(i[1])

plt.figure(figsize=(17,8))
plt.scatter(prc,rev,color='green')
plt.ylabel("Prices(Є/Euro)")
plt.xlabel("Reviews")
plt.xticks(rotation=0)
plt.xlim(0,500)
plt.title('Price VS Reviews')
plt.show()
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 13550 rows affected.

# %% [markdown]
# WHICH ROOMS CAN ACCOMMODATE 10-15MOST PEOPLE?

# %%
accomodation=%sql select DISTINCT(room_id), accommodates from airbnb_lisbon WHERE accommodates BETWEEN 10 AND 15 GROUP BY room_id ORDER BY accommodates desc LIMIT 40
accomodation
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 40 rows affected.
# [(646676, 15),
#  (649734, 15),
#  (877888, 15),
#  (1113112, 15),
#  (1504160, 15),
#  (2536555, 15),
#  (3047997, 15),
#  (3905464, 15),
#  (4253783, 15),
#  (4900949, 15),
#  (5561774, 15),
#  (7081091, 15),
#  (16371574, 15),
#  (16640916, 15),
#  (18578104, 15),
#  (819462, 14),
#  (920793, 14),
#  (1398805, 14),
#  (2685942, 14),
#  (3003018, 14),
#  (3421459, 14),
#  (5260704, 14),
#  (5599753, 14),
#  (6206281, 14),
#  (6473103, 14),
#  (8035071, 14),
#  (10758609, 14),
#  (13245390, 14),
#  (13945877, 14),
#  (14669220, 14),
#  (14692202, 14),
#  (15853480, 14),
#  (17472442, 14),
#  (17489136, 14),
#  (18066609, 14),
#  (18429653, 14),
#  (19320124, 14),
#  (1211272, 13),
#  (1760857, 13),
#  (3915496, 13)]

# %%
accomodation=%sql select DISTINCT(room_id), accommodates from airbnb_lisbon WHERE accommodates BETWEEN 10 AND 15 GROUP BY DISTINCT(room_id) ORDER BY accommodates desc limit 40
accomodation

rooms = []
acco = []
 
for i in accomodation:
    rooms.append(str(i[0]))
    acco.append(i[1])

plt.figure(figsize=(17,8))    
plt.bar(rooms, acco, color = 'orange')
plt.ylabel("number of accommodates")
plt.xlabel("rooms")
plt.xticks(rotation=90)
plt.title("Number of people per room")
plt.ylim(0,16)

plt.show()
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 40 rows affected.

# %% [markdown]
# HOW MANY BEDROOMS DOES EACH ROOM HAVE?

# %%
accomodation=%sql select DISTINCT(room_id), SUM(bedrooms) from airbnb_lisbon GROUP BY DISTINCT(room_id) ORDER BY SUM(bedrooms) DESC limit 40
accomodation

rooms = []
count_bedrooms = []
 
for i in accomodation:
    rooms.append(str(i[0]))
    count_bedrooms.append(i[1])

plt.figure(figsize=(17,8))    
plt.bar(rooms, count_bedrooms, color = 'brown')
plt.ylabel("number of accommodates")
plt.xlabel("rooms")
plt.xticks(rotation=90)
plt.title("Number of people per room")

plt.show()
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 40 rows affected.

# %% [markdown]
# WHICH NEIGHBORHOOD IS THE MOST EXPENSIVE?

# %%
price_rev = %sql select MAX(price), neighborhood from airbnb_lisbon GROUP BY neighborhood ORDER BY MAX(price) desc

max_price = []
neighbor = []
 
for i in price_rev:
    max_price.append(i[0])
    neighbor.append(i[1])

plt.figure(figsize=(17,8))    
plt.bar(neighbor, max_price, color = 'gold')
plt.ylabel("Prices(Є/Euro)")
plt.xlabel("neighborhood")
plt.xticks(rotation=90)
plt.title("Most Expensive Neighborhood")
# Out:
#    postgresql://gnsiobsurufrtp:***@ec2-18-234-17-166.compute-1.amazonaws.com:5432/d37pct9o6m3u5r
#  * postgresql://postgres:***@localhost:5432/postgres
# 24 rows affected.
# Text(0.5, 1.0, 'Most Expensive Neighborhood')
